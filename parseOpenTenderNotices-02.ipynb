# %%
import pandas as pd
import subprocess

# %%
lines = []
with open("openTenderNotice-ouvertAvisAppelOffres.csv", "r") as f:
    for l in f:
        lines.append(l)

# %%
class PreviousLine:
    def __init__(self, a, b, c, d):
        self.inQuotes = a
        self.s = b
        self.strings = c
        self.i = d
        
    def __str__(self):
        return str((self.inQuotes, self.s, "..." + self.strings[-1], self.i))


class CSVData:
    def __init__(self, lines):
        self.cols = [w.split('"')[1] for w in lines[0].split(',')]
        self.nCols = len(self.cols)
        self.lines = lines
        self.currentLineIndex = 1
        #
        cols = {w:i for i, w in enumerate(self.cols) if not "-fra" in w}
        self.wantedColumns = {(w.split('-')[0]): i for w, i in cols.items()}
        self.nWantedColumns = len(self.wantedColumns)
            
    def getNextRecords(self, k):
        records = []
        for i in range(k):
            try:
                record, self.currentLineIndex = self.nextRecord(self.currentLineIndex)
            except Exception as e:
                print((i, e))
                return records
            records.append(record)
        return records
        
    def nextRecord(self, lineIndex):
        i = lineIndex
        strings, previousLine = self.stringsFromLine(self.lines[i], None)
        #print(previousLine)
        
        while previousLine:
            i += 1
            strings, previousLine = self.stringsFromLine(self.lines[i], previousLine)
            #print(previousLine)   
        return strings, i + 1

    def stringsFromLine(self, l, previousLine=None):
        if previousLine:
            inQuotes = previousLine.inQuotes
            s = previousLine.s
            strings = previousLine.strings
            i = previousLine.i
        else:
            inQuotes = False
            s = ''
            strings = []
            i = 0
        for c in l:
            if c == '"':
                if inQuotes:
                    inQuotes = False
                    if i == self.nCols - 1:
                        strings.append(s)
                        i += 1
                else:
                    s = ''
                    inQuotes = True
            else:
                if inQuotes:
                    if c == "\n":
                        s += "\\n"
                    else:
                        s += c
                elif c == ',':
                    strings.append(s)
                    i += 1
        if i < self.nCols:
            # got not all columns
            previousLine = PreviousLine(inQuotes, s, strings, i)
            return (strings, previousLine)
        else:
            return (strings, None)

    def extractFields(self, record, fields=None):
        if not fields:
            fields = self.wantedColumns 
        return [r for i, r in enumerate(record) if i in fields.values()]

    def toDataFrame(self, records, fields=None):
        if not fields:
           fields = self.wantedColumns 
        recordsDict = {i: self.extractFields(record, fields) for i, record in enumerate(records)}
        df = pd.DataFrame.from_dict(recordsDict, orient='index', columns=fields.keys())
        return df

# %%
csvData = CSVData(lines)

# %%
importantColumns = ['title', 'tenderClosingDate', 'tenderStatus', 'unspscDescription', 'contractingEntityName', 'tenderDescription', 'noticeURL', 'attachment']

# %%
records = []
records.extend(csvData.getNextRecords(1000))
# Out:
# (684, IndexError('list index out of range'))

# %%
csvData = CSVData(lines)
records = []
records.extend(csvData.getNextRecords(684))

# %%
len(records)
# Out:
# 681

# %%
r = csvData.getNextRecords(1)
# Out:
# (0, IndexError('list index out of range'))

# %%
df = csvData.toDataFrame(records)
df_ = df.loc[:, importantColumns]

# %%
df.to_pickle("df.pkl")
df.to_csv("df.csv")

# %%
df_.head()
# Out:
#                                                title    tenderClosingDate  \
# 0  Electrical and Electrical Products (New Brunsw...  2024-06-25T11:00:00
# 1  Dental Services for Manitoba Region, FNIHB Pro...  2025-03-31T14:00:00
# 2  Water and Wastewater Audits - Alberta / Britis...  2024-07-16T13:00:00
# 3      Request for Information-Indigenous Businesses  2024-08-30T14:00:00
# 4              One (1) Intermediate Technical Writer  2024-07-05T14:00:00
#
#   tenderStatus                                  unspscDescription  \
# 0         Open                             *Electrical components
# 1         Open                                   *Dental services
# 2         Open                            *Environmental auditing
# 3         Open  *Information technology consultation services\...
# 4         Open                                 *Technical writing
#
#                       contractingEntityName  \
# 0            Department of National Defence
# 1                Indigenous Services Canada
# 2                             Melissa Smith
# 3  Employment and Social Development Canada
# 4            Department of National Defence
#
#                                    tenderDescription noticeURL  \
# 0  The Department of National Defence has a requi...
# 1  Indigenous Services Canada (ISC), First Nation...
# 2  DESCRIPTION:\nAgriculture and Agri-Food Canada...
# 3  Employment and Social Development Canada (ESDC...
# 4  NOTICE OF PROPOSED PROCUREMENT\n\nFile Number:...
#
#                                           attachment
# 0  https://canadabuys.canada.ca/sites/default/fil...
# 1  https://canadabuys.canada.ca/sites/default/fil...
# 2  https://canadabuys.canada.ca/sites/default/fil...
# 3  https://canadabuys.canada.ca/sites/default/fil...
# 4

# %%
minimalColumns = ['title', 'tenderClosingDate', 'unspscDescription', 'contractingEntityName', 'tenderDescription']
df_ = df.loc[:, minimalColumns]

# %%
df_.tenderStatus.value_counts()
# Out:
# tenderStatus
# Open    561
# ,        62
#          61
# Name: count, dtype: int64

# %%
df_.noticeURL.value_counts()
# Out:
# noticeURL
#                                                                                      252
# ,                                                                                    114
# https://discovery.ariba.com/rfx/19456899?extsite=MTk0NTY4OTlfQU4wMTQ4NDA1MDk5Mg==      1
# https://discovery.ariba.com/rfx/19894579?extsite=MTk4OTQ1NzlfQU4wMTQ4NDA1MDk5Mg==      1
# https://discovery.ariba.com/rfx/19870581?extsite=MTk4NzA1ODFfQU4wMTQ4NDA1MDk5Mg==      1
#                                                                                     ...
# https://www.merx.com/public/solicitations/2908823323/abstract?language=EN              1
# https://discovery.ariba.com/rfx/19771075?extsite=MTk3NzEwNzVfQU4wMTQ4NDA1MDk5Mg==      1
# https://discovery.ariba.com/rfx/19651439?extsite=MTk2NTE0MzlfQU4wMTQ4NDA1MDk5Mg==      1
# https://discovery.ariba.com/rfx/19781390?extsite=MTk3ODEzOTBfQU4wMTQ4NDA1MDk5Mg==      1
# https://discovery.ariba.com/rfx/19953509?extsite=MTk5NTM1MDlfQU4wMTQ4NDA1MDk5Mg==      1
# Name: count, Length: 320, dtype: int64

# %%
minimalColumns = ['title', 'tenderClosingDate', 'unspscDescription', 'contractingEntityName', 'tenderDescription']
df_ = df.loc[:, minimalColumns]
df_.head()
# Out:
#                                                title    tenderClosingDate  \
# 0  Electrical and Electrical Products (New Brunsw...  2024-06-25T11:00:00
# 1  Dental Services for Manitoba Region, FNIHB Pro...  2025-03-31T14:00:00
# 2  Water and Wastewater Audits - Alberta / Britis...  2024-07-16T13:00:00
# 3      Request for Information-Indigenous Businesses  2024-08-30T14:00:00
# 4              One (1) Intermediate Technical Writer  2024-07-05T14:00:00
#
#                                    unspscDescription  \
# 0                             *Electrical components
# 1                                   *Dental services
# 2                            *Environmental auditing
# 3  *Information technology consultation services\...
# 4                                 *Technical writing
#
#                       contractingEntityName  \
# 0            Department of National Defence
# 1                Indigenous Services Canada
# 2                             Melissa Smith
# 3  Employment and Social Development Canada
# 4            Department of National Defence
#
#                                    tenderDescription
# 0  The Department of National Defence has a requi...
# 1  Indigenous Services Canada (ISC), First Nation...
# 2  DESCRIPTION:\nAgriculture and Agri-Food Canada...
# 3  Employment and Social Development Canada (ESDC...
# 4  NOTICE OF PROPOSED PROCUREMENT\n\nFile Number:...

# %%
list(df_.unspscDescription.value_counts().index)
# Out:
# ['',
#  ',',
#  '*Product and material trailers',
#  '*Laboratory and scientific equipment',
#  '*Office furniture',
#  '*Architectural engineering',
#  '*Heavy construction machinery and equipment',
#  '*Water transport vessel maintenance and repair services',
#  '*Motor vehicles',
#  '*Computer services',
#  '*Building and Facility Construction and Maintenance Services',
#  '*Commercial marine craft',
#  '*Software',
#  '*Nonresidential building construction services',
#  '*Clothing',
#  '*Cleaning and janitorial services',
#  '*Audit services',
#  '*Decontamination services',
#  '*Information technology consultation services',
#  '*Building and facility maintenance and repair services',
#  '*Laboratory and Measuring and Observing and Testing Equipment',
#  '*Building and Facility Construction and Maintenance Services\\n*Nonresidential building construction services',
#  '*Material handling machinery and equipment',
#  '*Professional engineering services',
#  '*Snow plow truck',
#  '*Product research and development service',
#  '*Roofing service',
#  '*Chartered bus services',
#  '*Marine craft systems and subassemblies',
#  '*Electrical cable and accessories\\n*Electronic component parts and raw materials and accessories\\n*Distribution and control centers and accessories\\n*Electrical boxes and enclosures and fittings and accessories\\n*Electrical lugs plugs and connectors\\n*Electrical controls and accessories\\n*Circuit protection devices and accessories\\n*Electrical hardware and supplies\\n*Electrical safety devices and accessories\\n*Electrical transmission and distribution equipment\\n*Electrical switches and accessories\\n*Electrical relays and accessories',
#  '*Specialty building and trades services',
#  '*Temporary personnel services',
#  '*Logs',
#  '*Closed circuit television CCTV system',
#  '*Real estate services',
#  '*Professional engineering services\\n*Architectural engineering',
#  '*Earth moving machinery',
#  '*General building and office cleaning and maintenance services',
#  '*Landscaping services\\n*Snow removal services\\n*Exterior grounds maintenance',
#  '*Software or hardware engineering',
#  '*Audio and visual equipment',
#  '*Lighting installation services',
#  '*Containers and storage',
#  '*Agricultural machinery for harvesting',
#  '*Warehousing equipment and supplies',
#  '*Seating',
#  '*Floor laying services\\n*Concrete installation and repair services',
#  '*Resins',
#  '*Building and facility maintenance and repair services\\n*Building maintenance and repair services\\n*Facility maintenance and repair services\\n*Infrastructure maintenance and repair services',
#  '*Professional procurement services',
#  '*Building construction management',
#  '*Media monitoring service',
#  '*Building and Construction Machinery and Accessories',
#  '*Project administration or planning\\n*Project monitoring and evaluation\\n*Project impact assessment',
#  '*Marine construction services',
#  '*Garbage collection or destruction or processing or disposal\\n*Garbage dump',
#  '*Medical or surgical equipment repair',
#  '*Fall protection and rescue equipment',
#  '*Hazardous waste disposal',
#  '*General building construction',
#  '*Hardware and fittings',
#  '*Glass or window cleaners\\n*Window or window blind cleaning services',
#  '*Water treatment and supply equipment',
#  '*Marine craft systems and subassemblies\\n*Recycling services',
#  '*Helium gas He',
#  '*Industrial refrigerators',
#  '*Fresh fruits\\n*Fresh vegetables',
#  '*Musical Instruments and Games and Toys and Arts and Crafts and Educational Equipment and Materials and Accessories and Supplies\\n*Musical Instruments and parts and accessories\\n*Musical instrument parts and accessories\\n*Musical instrument sets',
#  '*Relocation services',
#  '*Packing tools',
#  '*Facility maintenance and repair services',
#  '*Commercial marine craft\\n*Utility landing watercraft',
#  '*Information Technology Service Delivery',
#  '*Mechanical engineering\\n*Electrical engineering services',
#  '*Engineering and Research and Technology Based Services',
#  '*Diesel fuel',
#  '*Environmental Impact Assessment EIA services\\n*Environmental advisory services\\n*Environmental reporting services',
#  '*Fire fighting pump truck',
#  '*Product testing',
#  '*Business and corporate management consultation services\\n*Strategic planning consultation services\\n*Organizational structure consultation\\n*Information technology consultation services\\n*Business intelligence consulting services\\n*Human resources consulting service\\n*Process and procedures management consultation service\\n*Professional procurement services\\n*Systems integration design',
#  '*Software\\n*Development software\\n*Configuration management software\\n*Enterprise application integration software\\n*Graphical user interface development software\\n*Requirements analysis and system architecture software\\n*Web platform development software\\n*Systems integration design',
#  '*Aircraft probes or sensors',
#  '*Prefabricated structures\\n*Prefabricated commercial and industrial structures',
#  '*Planting services\\n*Crop planting and cultivation',
#  '*Gait training products',
#  '*Toxic gas detection services',
#  '*Professional engineering services\\n*Civil engineering',
#  '*Environmental Services\\n*Environmental planning\\n*Environmental reporting services',
#  '*Supply of water',
#  '*Tanker truck and trailer rental service',
#  '*Snow removal services',
#  '*Tents',
#  '*Scheduled bus services\\n*Chartered bus services\\n*Vehicle rental',
#  '*Software\\n*Cloud-based data access and sharing software\\n*Internet cloud storage service\\n*Cloud-based platform as a service\\n*Cloud-based infrastructure as a service\\n*Cloud backup as a service\\n*Cloud storage as a service\\n*Cloud firewalls as a service\\n*Cloud network devices as a service',
#  '*Agricultural machinery for soil preparation',
#  '*Loading equipment\\n*Transportation components and systems\\n*Fuel tanks and systems\\n*Exhaust and emission controls\\n*Drivetrain systems\\n*Automotive chassis\\n*Electrical cable and accessories\\n*Valves\\n*Pressure measuring and control instruments\\n*Transportation related equipment and instruments',
#  '*Industrial optics\\n*Lenses and prisms\\n*Mirrors\\n*Optical filters\\n*Optical domes\\n*Optical device accessories\\n*Miscellaneous optical components\\n*Viewing and observing instruments and accessories\\n*Camera based vision systems for automated data collection\\n*Industry specific software\\n*Satellite image treatment software\\n*Astronomical camera\\n*Infrared IR telescope\\n*Surveillance and detection equipment\\n*Astronomy\\n*Space engineering service',
#  '*Electrical cable and accessories\\n*Panels or panelling\\n*Mounting hardware\\n*Brackets and braces\\n*Gaskets\\n*Antenna accessory\\n*Markers\\n*Caps\\n*Labels\\n*Identification markers',
#  '*Garbage collection or destruction or processing or disposal',
#  '*Machine installation and maintenance and repair services',
#  '*Bathymetric surveys',
#  '*Refuse disposal and treatment',
#  '*Fabrics and leather materials',
#  '*Project management\\n*Business administration services\\n*Financial assistance',
#  '*Environmental impact assessment\\n*Environmental standards\\n*Environmental reporting services',
#  '*Fire alarm systems\\n*Standby or emergency power installation service\\n*Fire alarm maintenance or monitoring',
#  '*Lighting Fixtures and Accessories',
#  '*Storage and handling equipment and supplies',
#  '*General building and office cleaning and maintenance services\\n*Building cleaning services\\n*Window or window blind cleaning services\\n*Building component cleaning services\\n*Floor waxing or carpet cleaning',
#  '*Metal cutting machinery and accessories',
#  '*Trade shows and exhibits\\n*Project based communications service',
#  '*Marine navigational or communication services',
#  '*Project monitoring and evaluation',
#  '*Civil engineering\\n*Architectural engineering\\n*Building construction management\\n*Plant or facility infrastructure engineering\\n*Energy or utility consulting service\\n*Landscape architecture and design service\\n*Lighting engineering service\\n*Subdivison planning service\\n*Earthworks engineering\\n*Wastewater engineering',
#  '*Furniture\\n*Chairs\\n*Office furniture',
#  '*Fuel filters',
#  '*Feminine hygiene products',
#  '*Electrical components',
#  '*Government affairs and community relations consultation service',
#  '*Signage and accessories\\n*Tags\\n*Labels\\n*Signage\\n*Identification documents\\n*Signage equipment\\n*Electrical labels',
#  '*Welding machinery',
#  '*All terrain vehicles tracked or wheeled\\n*Amphibious vehicle',
#  '*Elevators\\n*Elevator maintenance services\\n*Architectural engineering',
#  '*Mobile medical services kits\\n*Mobile medical services resuscitation products',
#  '*Marine fuel',
#  '*Electrical boxes and enclosures and fittings and accessories',
#  '*Laboratory and Measuring and Observing and Testing Equipment\\n*Electrical measuring and testing equipment and accessories\\n*Electronic and communication measuring and testing instruments\\n*Software\\n*Data base user interface and query software\\n*Compliance software\\n*Laboratory equipment maintenance\\n*Software maintenance and support\\n*Computer software licensing service',
#  '*Business and corporate management consultation services',
#  '*Transducers',
#  '*Printing and writing paper\\n*Drafting papers\\n*Focus group and public feedback meeting facilitation and analysis\\n*Cultural and ethnic group relations consultation and engagement\\n*Indigenous peoples relations consultation and engagement\\n*Government relations consultation and engagement\\n*Community relations consultation and engagement\\n*Writing and translations\\n*Publishing\\n*Textbook or research publishing',
#  '*Geographic information system\\n*Forestry\\n*Aerial photography services',
#  '*Drainage earth and sand barrel\\n*Drainage channel\\n*Drainage services\\n*Underground utilities construction service\\n*Earthworks engineering',
#  '*Viewing and observing instruments and accessories',
#  '*Medical biohazard disposal products',
#  '*International patent\\n*Nation based patent',
#  '*Marine signaling systems\\n*Navigational services\\n*Marine navigational or communication services',
#  '*Healthcare provider specialist services',
#  '*Information technology IT management services',
#  '*Bird proofing services',
#  '*Property management services',
#  '*Lockers',
#  '*Crane truck',
#  '*Environmental standards\\n*Specification standardization services',
#  '*Military education\\n*Training planning, facilitation and delivery services\\n*Military tactics',
#  '*Professional engineering services\\n*Electrical engineering services',
#  '*Van trucks',
#  '*Elements and gases',
#  '*Sandals',
#  '*Furniture',
#  '*Concrete installation and repair services',
#  '*Language schooling',
#  '*Bolts',
#  '*Transformer oil or insulating oil\\n*Power line inspection service\\n*Industrial electric power distribution',
#  '*Equipment cases',
#  '*Management advisory services',
#  '*Furniture and Furnishings',
#  '*Advertising agency services',
#  '*Paper shredding machines or accessories',
#  '*Camping and wilderness facilities',
#  '*Waste material handling and recycling systems\\n*Waste containers and accessories',
#  '*Animal containment and habitats',
#  '*Pool cleaner\\n*Swimming pool and spa equipment and supplies',
#  '*Vehicle bodies and trailers\\n*Product and material trailers',
#  '*Fertilizers and plant nutrients and herbicides',
#  '*Editing services',
#  '*Trailer, travel or caravan',
#  '*Heating and cooling and air conditioning HVAC construction and maintenance services',
#  '*Information Technology Service Delivery\\n*Cloud-based software as a service\\n*Enterprise resource planning software as a service',
#  '*Information technology consultation services\\n*Information technology IT management services',
#  '*Engines\\n*Engine Repair Kit\\n*Engineering equipment maintenance services',
#  '*Geographic information system\\n*Geographic information system GIS services\\n*Demining geographical or geospatial information system GIS',
#  '*Exhaust hood or fan clearing',
#  '*Laboratory ionic equipment',
#  '*Aircraft digital altitude control systems',
#  '*Camera parts and accessories\\n*Camera flashes or lighting\\n*Camera enclosures or covers',
#  '*Labor training or development',
#  '*Foreign languages resources\\n*Language schooling',
#  '*Metal forming machinery and accessories',
#  '*Prefabricated buildings and structures',
#  '*Lathes and turning centers',
#  '*Meat and poultry products\\n*Dairy products and eggs\\n*Prepared and preserved foods\\n*Fresh fruits\\n*Fresh vegetables',
#  '*Ammunition\\n*Defense or law enforcement ammunition',
#  '*Marine craft systems and subassemblies\\n*Marine construction services',
#  '*Body armour',
#  '*Dust collectors',
#  '*Fitness equipment',
#  '*Strategic planning consultation services\\n*Business intelligence consulting services',
#  '*Environmental Services\\n*Environmental rehabilitation',
#  '*Vocational training',
#  '*Megaphones',
#  '*Minibuses',
#  '*Environmental management\\n*Pollution tracking and monitoring and rehabilitation',
#  '*Land surveying',
#  '*Indicating and recording instruments\\n*Weapon or explosives detectors and supplies\\n*Surveillance and detection equipment\\n*Security metal detector',
#  '*Laboratory furnaces and accessories',
#  '*Personal safety and protection\\n*Fall protection and rescue equipment\\n*Toxic substances protection services',
#  '*Automotive garage and service station construction services',
#  '*Water main construction service',
#  '*Environmental decontamination services',
#  '*Events management\\n*Cloud-based software as a service',
#  '*Building maintenance service',
#  '*Grenades',
#  '*Renovation of buildings or landmarks or monuments\\n*Commercial and office building construction services\\n*Commercial and office building renovation and repair service',
#  '*Dinghies\\n*Marine craft systems and subassemblies',
#  '*Uniforms\\n*Furniture\\n*Showcases\\n*Interior design or decorating\\n*Food and beverage industries\\n*Transport services\\n*Sponsorships',
#  '*Truck tractors',
#  '*Technology teaching aids and materials',
#  '*Software\\n*Software maintenance and support',
#  '*Network security equipment\\n*Security and protection software\\n*National Defense and Public Order and Security and Safety Services',
#  '*Roofing service\\n*Specialty building and trades services',
#  '*Security guard services',
#  '*Aircraft',
#  '*Mechanical engineering',
#  '*All terrain cranes\\n*Armored fighting vehicles',
#  '*Live animals\\n*Domestic pet products\\n*Animal feed\\n*Animal containment and habitats\\n*Saddlery and harness goods\\n*Seeds and bulbs and seedlings and cuttings\\n*Floriculture and silviculture products\\n*Fertilizers and plant nutrients and herbicides\\n*Pest control products\\n*Minerals and ores and metals\\n*Earth and stone\\n*Non edible plant and forestry products\\n*Non edible animal products\\n*Scrap and waste materials\\n*Fibers and threads and yarns\\n*Fabrics and leather materials\\n*Alloys\\n*Metal oxide\\n*Metal waste scrap and by products\\n*Explosive materials\\n*Elements and gases\\n*Additives\\n*Colorants\\n*Waxes and oils\\n*Solvents\\n*Compounds and mixtures\\n*Pharmaceutical drug precursors\\n*Rubber and elastomers\\n*Resins and rosins and other resin derived materials\\
#  '*Snow removal services\\n*Exterior grounds maintenance',
#  '*Military services and national defense',
#  '*Land surveying\\n*Aerial photography services',
#  '*Building maintenance and repair services',
#  '*Satellite access equipment\\n*Satellite launch services\\n*Engineering and Research and Technology Based Services\\n*Satellite imaging and image processing service\\n*Military science and research',
#  '*Cartography',
#  '*Laboratory environmental conditioning equipment',
#  '*Archaeological services',
#  '*Aerospace systems and components and equipment',
#  '*Medical Equipment and Accessories and Supplies',
#  '*Specialized trade construction and maintenance services',
#  '*Fixed wing training aircraft or trainer\\n*Training process as a service\\n*Driving and flying and sailing\\n*Military education\\n*Training planning, facilitation and delivery services\\n*Curriculum development service',
#  '*Developmental and professional teaching aids and materials and accessories and supplies\\n*Electronic learning aids\\n*Specialized educational services\\n*Military education\\n*Educational technology',
#  '*Police vehicles',
#  '*Commercial and office building prefabricated erection service\\n*Portable or modular office rental service\\n*Prefabricated commercial and industrial buildings and structures',
#  '*Tugboat services\\n*Naval architecture',
#  '*Writing and translations',
#  '*Bridge construction and repair service',
#  '*Food and beverage industries\\n*Food and nutrition services\\n*Restaurants and catering\\n*Eating and drinking establishments\\n*Banquet and catering services\\n*Carryout and takeaway services',
#  '*Filter assembly\\n*Laboratory filtering equipment and supplies',
#  '*Marine transport',
#  '*Highway and road maintenance service',
#  '*Electrical system services\\n*Fire alarm maintenance or monitoring',
#  '*Military science and research',
#  '*Building maintenance and repair services\\n*Government affairs and community relations consultation service\\n*Trade shows and exhibits\\n*Professional engineering services\\n*Architectural engineering\\n*Building construction management\\n*Performing arts',
#  '*Nitrogen N\\n*Air or gas tanks or cylinders\\n*Chemical tanks\\n*Liquified gas tank or cylinder',
#  '*Prefabricated buildings and structures\\n*Prefabricated commercial and industrial buildings and structures',
#  '*Earth metals\\n*Extraction',
#  '*Heavy construction services',
#  '*Navigational equipment and instruments\\n*Underwater communication system\\n*Underwater exploration',
#  '*Athletic wear',
#  '\\n',
#  '*Wastewater engineering',
#  '*Electric vehicle charging systems',
#  '*Technical writing',
#  '*Information technology consultation services\\n*Project management',
#  '*Environmental auditing',
#  '*Astronomy',
#  '*Batteries and cells and accessories\\n*Emergency lighting and accessories',
#  '*Accommodation furniture\\n*Commercial and industrial furniture\\n*Panel systems\\n*Casegood and non modular systems\\n*Freestanding furniture\\n*Computer support furniture\\n*Seating\\n*Desking systems\\n*Office furniture installation or reconfiguration service\\n*Office furniture repair service',
#  '*Road cargo transport\\n*Local area trucking services\\n*Regional or national trucking services',
#  '*Promotional or advertising printing',
#  '*Broadcast domain controller',
#  '*Printing',
#  '*Management information systems MIS',
#  '*Flatbed truck\\n*Automotive chassis\\n*Product and material trailers',
#  '*Agricultural machinery for planting and seeding',
#  '*Vocational rehabilitation services',
#  '*X ray baggage inspection system\\n*Security metal detector',
#  '*Motor vehicles\\n*Dump trucks\\n*Delivery trucks\\n*Cargo trucks\\n*Flatbed truck\\n*Van trucks\\n*Truck tractors',
#  '*Pesticides or pest repellents',
#  '*Fishery research or experimentation services',
#  '*Hand tools',
#  '*Lifts',
#  '*Busses',
#  '*Building and facility maintenance and repair services\\n*Building maintenance and repair services\\n*Facility maintenance and repair services\\n*Snow removal services\\n*Infrastructure maintenance and repair services',
#  '*Paving equipment',
#  '*Robotics\\n*Robot components',
#  '*Solid state drive SSD\\n*Office machines and their supplies and accessories\\n*Cassette disposal equipment and accessories\\n*Cassette or tape shredders',
#  '*Aircraft equipment',
#  '*Job evaluation service',
#  '*Electrical equipment maintenance and repair service',
#  '*Electrical system services\\n*Electronic controls installation service\\n*Electrical equipment maintenance and repair service\\n*Electrical engineering services',
#  '*Drugs and Pharmaceutical Products',
#  '*Radio frequency transmitters or receivers',
#  '*Railroad support equipment and systems',
#  '*Database design\\n*Database analysis service\\n*Database information retrieval\\n*Online database information retrieval service\\n*Database management system software maintenance\\n*Database management as a service',
#  '*HVAC mechanical construction service',
#  '*Dump trucks',
#  '*Aviation fuel',
#  '*Hydrogen H\\n*Helium gas He',
#  '*Landscaping services\\n*Exterior grounds maintenance',
#  '*Asphalts\\n*Highway and road paving service',
#  '*Bread and bakery products\\n*Flour tortillas',
#  '*Heating and cooling and air conditioning HVAC installation and maintenance service',
#  '*Specialized public building construction services\\n*Architectural engineering',
#  '*Defense or law enforcement ammunition',
#  '*Chartered airplane travel',
#  '*Independent dispute mediation or arbitration service\\n*Business administration services\\n*Computer services\\n*Healthcare provider support persons\\n*Health administration services\\n*Diagnoses of mental and behavioral disorders\xa0\xa0\\n*Curriculum development service',
#  '*Freight containers',
#  '*Roof systems\\n*Roofing and siding and sheet metal services',
#  '*Nitrogen N',
#  '*Windows\\n*Glass products',
#  '*Reservoirs\\n*Freight containers',
#  '*Building and Facility Construction and Maintenance Services\\n*Building and facility maintenance and repair services\\n*Building maintenance and repair services\\n*Facility maintenance and repair services\\n*Snow removal services\\n*Infrastructure maintenance and repair services',
#  '*Bankruptcy law services\\n*Liquidation law services',
#  '*Forklifts',
#  '*Structures and Building and Construction and Manufacturing Components and Supplies',
#  '*Weight measuring instruments']

# %%
specificUnspscDescriptions = \
    [    
        '*Software',
        '*Computer services',
        '*Information technology consultation services',
        '*Product research and development service',
        '*Media monitoring service',
        '*Information Technology Service Delivery',
        '*Engineering and Research and Technology Based Services',
        '*Product testing',
        '*Editing services',
        '*Information retrieval systems',
        '*Writing and translations',
        '*Technical writing',
        '*Analytical or scientific software',
        '*Industrial optics'
    ]

# %%
f = lambda x: '*Technical writing' in x
df2 = df_.loc[df_.unspscDescription.apply(f), :]
df2
# Out:
#                                                  title    tenderClosingDate  \
# 4                One (1) Intermediate Technical Writer  2024-07-05T14:00:00
# 393  Industry Sustainment Business Case Analysis (S...  2025-06-30T14:00:00
#
#                                      unspscDescription  \
# 4                                   *Technical writing
# 393  *Water quality assessment services\n*Water tes...
#
#                                  contractingEntityName  \
# 4                       Department of National Defence
# 393  Procurement Innovation Initiatives Directorate...
#
#                                      tenderDescription
# 4    NOTICE OF PROPOSED PROCUREMENT\n\nFile Number:...
# 393  Industry Sustainment Business Case Analysis (S...

# %%
f = lambda x: '*Analytical or scientific software' in x
df2 = df_.loc[df_.unspscDescription.apply(f), :]
df2
# Out:
#                                                  title    tenderClosingDate  \
# 317  Invitation to Qualify to Artificial Intelligen...  2025-09-30T14:00:00
#
#                       unspscDescription  \
# 317  *Analytical or scientific software
#
#                                  contractingEntityName  \
# 317  Department of Public Works and Government Serv...
#
#                                      tenderDescription
# 317  This publication replaces the following AI Sou...

# %%
f = lambda x: '*Media monitoring service' in x
df2 = df_.loc[df_.unspscDescription.apply(f), :]
df2
# Out:
#                                                  title    tenderClosingDate  \
# 174  Reissuance - Media Monitoring Services - EN578...  2028-12-31T14:00:00
# 497  RFQ Canadian and International Ethnic Media Mo...  2024-07-03T14:00:00
#
#              unspscDescription  \
# 174  *Media monitoring service
# 497  *Media monitoring service
#
#                                  contractingEntityName  \
# 174  Department of Public Works and Government Serv...
# 497  Department of Public Works and Government Serv...
#
#                                      tenderDescription
# 174  This event is to reissue on CanadaBuys the Req...
# 497  RFQ under supply arrangement EN578-191713 for ...

# %%
f = lambda x: '*Information retrieval systems' in x
df2 = df_.loc[df_.unspscDescription.apply(f), :]
df2
# Out:
#                                                  title    tenderClosingDate  \
# 248  E60PI-23AGNT-C - Ongoing Qualification to RFSA...  2029-02-09T14:00:00
#
#                   unspscDescription  \
# 248  *Information retrieval systems
#
#                                  contractingEntityName  \
# 248  Department of Public Works and Government Serv...
#
#                                      tenderDescription
# 248  THIS IS AN ONGOING REQUEST FOR SUPPLY ARRANGEM...

# %%
dfs = []
for c in specificUnspscDescriptions:
    f = lambda x: c in x
    df2 = df_.loc[df_.unspscDescription.apply(f), :]
    dfs.append(df2)

# %%
df_out = pd.concat(dfs)[['title', 'tenderDescription']]
df_out.head(3)
# Out:
#                                                  title  \
# 267  Request for Information for Environment and Cl...
# 279  CBSO-Application Portfolio Management (GC APM)...
# 283  Software Licensing Supply Arrangement (SLSA) RFSA
#
#                                      tenderDescription
# 267  ECCC is launching this RFI to engage with and ...
# 279  AMENDMENT TO CLOSING TIME: Please disregard th...
# 283  IMPORTANT NOTICE: Please submit offers to the ...

# %%
df_out.tail()
# Out:
#                                                  title  \
# 4                One (1) Intermediate Technical Writer
# 393  Industry Sustainment Business Case Analysis (S...
# 317  Invitation to Qualify to Artificial Intelligen...
# 267  Request for Information for Environment and Cl...
# 489  Request for Information Surveillance of Space ...
#
#                                      tenderDescription
# 4    NOTICE OF PROPOSED PROCUREMENT\n\nFile Number:...
# 393  Industry Sustainment Business Case Analysis (S...
# 317  This publication replaces the following AI Sou...
# 267  ECCC is launching this RFI to engage with and ...
# 489  Through this Request for Information (RFI), Pu...

# %%
f = lambda x: '*Industrial optics' in x
df_optics = df_.loc[df.unspscDescription.apply(f), :]
df_optics
# Out:
#                                                  title    tenderClosingDate  \
# 267  Request for Information for Environment and Cl...  2024-07-26T15:00:00
# 489  Request for Information Surveillance of Space ...  2024-06-25T14:00:00
#
#                                      unspscDescription  \
# 267  *Live animals\n*Domestic pet products\n*Animal...
# 489  *Industrial optics\n*Lenses and prisms\n*Mirro...
#
#                                  contractingEntityName  \
# 267              Environment and Climate Change Canada
# 489  Department of Public Works and Government Serv...
#
#                                      tenderDescription
# 267  ECCC is launching this RFI to engage with and ...
# 489  Through this Request for Information (RFI), Pu...
